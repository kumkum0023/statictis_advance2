# %% [markdown]
# Que-1  What is hypothesis testing in statistics8
# Ans-
# A statistical hypothesis test is a method of statistical inference used to decide whether the data provide sufficient evidence to reject a particular hypothesis. A statistical hypothesis test typically involves a calculation of a test statistic.

# %% [markdown]
# Que-2  What is the null hypothesis, and how does it differ from the alternative
#         hypothesis?
# Ans-   The null hypothesis (H0) proposes that there is no significant relationship or difference between variables, while the alternative hypothesis (Ha) suggests that there is a significant relationship or difference. Essentially, the null hypothesis represents the status quo or default assumption, while the alternative hypothesis is the statement researchers are trying to find evidence for.
# Here's a more detailed breakdown:
# Null Hypothesis (H0):
# States there is no relationship, effect, or difference between variables.
# Often represents the status quo or default assumption.
# Researchers aim to disprove or reject the null hypothesis.

# %% [markdown]
# Que-3 What is the significance level in hypothesis testing, and why is it
#       important?
# Ans-
# The significance level in hypothesis testing, often denoted by α (alpha), is the threshold used to decide whether to reject the null hypothesis (H₀). It represents the probability of making a Type I error, which occurs when we reject a true null hypothesis.
#
# Common Significance Levels
# α = 0.05 (5%) – most commonly used
#
# α = 0.01 (1%) – for more stringent tests
#
# α = 0.10 (10%) – sometimes used in exploratory research
#
# Why Is the Significance Level Important?
# Controls Error Risk:
#
# It sets the acceptable risk of falsely rejecting H₀.
#
# For example, if α = 0.05, there's a 5% chance of concluding there is an effect when there actually isn’t.
#
# Decision-Making Threshold:
#
# In hypothesis testing, we compare the p-value to α.
#
# If p-value ≤ α: reject H₀.
#
# If p-value > α: fail to reject H₀.

# %% [markdown]
# Que-4 What does a P-value represent in hypothesis testing?
# Ans- Definition
# The p-value is the probability of obtaining a test statistic at least as extreme as the one observed, assuming the null hypothesis is true.
#
# Interpretation
# A small p-value (typically ≤ α) indicates strong evidence against H₀, so you reject the null hypothesis.
#
# A large p-value suggests weak evidence against H₀, so you fail to reject the null hypothesis.

# %% [markdown]
#     Que5- How do you interpret the P-value in hypothesis testing?
#     ANS- How  to Interpret the P-Value in Hypothesis Testing
# The p-value helps you decide whether the evidence from your sample data is strong enough to reject the null hypothesis (H₀).
#
# 🔍 Step-by-Step Interpretation
# Understand what the p-value represents:
#
# It’s the probability of observing your sample result (or one more extreme) if the null hypothesis is actually true.
#
# Compare the p-value to your chosen significance level (α):
#
# Common choices for α: 0.05, 0.01, or 0.10
#
# Make a decision:
#
# ✅ If p-value ≤ α: Reject H₀ → The result is statistically significant.
#
# ❌ If p-value > α: Fail to reject H₀ → The result is not statistically significant

# %% [markdown]
# Que-6 What are Type 1 and Type 2 errors in hypothesis testing?
# Ans - Type 1 Error (False Positive)
# Definition: Rejecting the null hypothesis when it is actually true.
#
# Symbol: α (alpha) – the significance level of the test.
#
# Example: You conclude a new drug works better than a placebo when in reality, it doesn’t.
#
# Consequence: You mistakenly detect an effect that isn't really there.
#
#
# Type 2 Error (False Negative)
# Definition: Failing to reject the null hypothesis when it is actually false.
#
# Symbol: β (beta)
#
# Power of a test:
# 1
# −
# 𝛽
# 1−β, which represents the probability of correctly rejecting H₀ when it’s false.
#
# Example: You conclude a new teaching method has no effect when it actually improves performance.
#
# Consequence: You miss a real effect or difference.

# %% [markdown]
# Que-7  What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# Ans -
# 🔁 Two-Tailed Test
# Used when:
# You are testing for any difference from the null hypothesis, in either direction (greater or smaller).
#
# 🔹 Hypotheses Example:
# H₀: μ = 100
#
# H₁: μ ≠ 100
#
# 🔹 Meaning:
# You're testing whether the mean is either less than or greater than 100.
#
# The rejection region is split between both tails of the distribution.
#
# 🔹 Significance Level:
# If α = 0.05, then 0.025 in each tail.
#
# 🔹 Use when:
# You care about any change, not just a specific direction.
#
# ➡️ One-Tailed Test
# 🔹 Used when:
# You are testing for a difference in only one direction.
#
# 🔹 Hypotheses Example:
# H₀: μ ≤ 100
#
# H₁: μ > 100
# (Right-tailed)
#
# OR
#
# H₀: μ ≥ 100
#
# H₁: μ < 100
# (Left-tailed)
#
# 🔹 Meaning:
# You're testing whether the mean is only greater than or only less than 100.
#
# The entire rejection region is in one tail.
#
# 🔹 Significance Level:
# All of α (e.g., 0.05) is placed in one tail.
#
# 🔹 Use when:
# You have a specific prediction about the direction of the effect.

# %% [markdown]
# QUE -8 What is the Z-test, and when is it used in hypothesis testing?
# Ans - A Z-test is a statistical test used to determine whether there is a significant difference between a sample statistic (like a mean or proportion) and a population parameter, under the assumption that the population follows a normal distribution.
#
# It relies on the Z-score, which measures how many standard deviations a data point is from the population mean.
#
# ✅ When to Use a Z-Test
# You use a Z-test when:
#
# The population standard deviation (σ) is known,
#
# The sample size is large (typically n ≥ 30),
#
# The data is approximately normally distributed (especially important for small samples)

# %% [markdown]
# Que-9 How do you calculate the Z-score, and what does it represent in hypothesis testing?
# Ans- ### 🔢 **How to Calculate the Z-Score**
#
# The **Z-score** is a standardized value that tells you how many **standard deviations** an observation or sample statistic is from the population mean.
#
# #### ✅ **Formula for Z-Score (Single Observation)**
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Where:
#
# * $X$ = individual data point
# * $\mu$ = population mean
# * $\sigma$ = population standard deviation
#
# ---
#
# #### ✅ **Formula for Z-Score (Sample Mean, for Hypothesis Testing)**
#
# $$
# Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
# $$
#
# Where:
#
# * $\bar{X}$ = sample mean
# * $\mu$ = population mean under the null hypothesis
# * $\sigma$ = population standard deviation
# * $n$ = sample size
#
# This is the version used in **Z-tests**.
#
# ---
#
# ### 🧠 **What Does the Z-Score Represent?**
#
# * The Z-score tells you how far (in standard deviations) your data is from the **null hypothesis mean**.
# * It allows you to use the **standard normal distribution (mean = 0, SD = 1)** to calculate probabilities and compare against critical values.
#
# ---
#
# ### 📊 **Interpreting Z-Scores**
#
# | **Z-Score** | **Interpretation**                       |
# | ----------- | ---------------------------------------- |
# | 0           | Exactly at the mean                      |
# | ±1          | 1 SD away from the mean                  |
# | ±2          | 2 SDs away from the mean                 |
# | ±3          | 3 SDs away from the mean (very unlikely) |
#
# * A **large absolute Z-score** indicates your sample result is **far from what’s expected** under the null hypothesis.
# * You compare this Z-score to a **critical value** from the Z-table (e.g., ±1.96 for a 5% significance level in a two-tailed test).
#
# ---

# %% [markdown]
# QUE - 10  What is the T-distribution, and when should it be used instead of the normal distribution?
# ANS - The T-distribution (also called Student’s t-distribution) is a probability distribution used in statistical inference when dealing with small sample sizes and/or when the population standard deviation (σ) is unknown.
#
# It looks similar to the normal distribution but has heavier tails, meaning it accounts for more variability — which is important when working with limited data.
#
# ✅ When to Use the T-Distribution (Instead of the Normal Distribution)
# Use the t-distribution when:
#
# ✅ The sample size is small (typically n < 30),
#
# ✅ The population standard deviation (σ) is unknown, and
#
# ✅ The data is approximately normally distributed or the sample size is large enough for the Central Limit Theorem to apply.

# %% [markdown]
# QUE-11 What is the difference between a Z-test and a T-test?
# ANS - Both Z-tests and T-tests are statistical methods used in hypothesis testing to determine whether there's a significant difference between means or proportions. The key difference lies in the information you have about the population and the size of your sample.
#
# 🔍 Comparison Table
# Feature	Z-Test	T-Test
# Population Standard Deviation (σ)	Known	Unknown
# Sample Size (n)	Typically large (n ≥ 30)	Typically small (n < 30)
# Distribution Used	Standard normal distribution (Z)	T-distribution
# Shape of Distribution	Symmetrical, thinner tails	Symmetrical, heavier tails (more uncertainty)
# Use Case	When σ is known and sample is large	When σ is unknown, especially with smaller samples
# Example	Testing a mean height with known σ in a large sample	Testing a new teaching method with small class samples

# %% [markdown]
# QUE-12 What is the T-test, and how is it used in hypothesis testing?
# Ans - A T-test is a statistical test used to determine whether there is a significant difference between means, especially when the population standard deviation is unknown and/or the sample size is small.
#
# It’s commonly used in research to test hypotheses about:
#
# The mean of a single group
#
# The difference between two groups
#
# The difference between paired observations (before/after studies)
#
# ✅ When to Use a T-Test
# Use a T-test when:
#
# You're testing hypotheses about means
#
# The population standard deviation (σ) is unknown
#
# The sample size is small (typically n < 30)
#
# The data is approximately normally dis

# %% [markdown]
# QUE-13 What is the relationship between Z-test and T-test in hypothesis testing?
# ANS - Relationship Between Z-Test and T-Test in Hypothesis Testing
# Both the Z-test and T-test are used to test hypotheses about population parameters (typically the mean) and assess whether there is a statistically significant difference between observed data and a population. However, they are applied in different circumstances depending on sample size and knowledge of the population's standard deviation.
#
# 🔍 Key Differences between Z-Test and T-Test
# Feature	Z-Test	T-Test
# Population Standard Deviation (σ)	Known	Unknown
# Sample Size (n)	Typically large (n ≥ 30)	Typically small (n < 30)
# Distribution	Standard normal distribution (Z-distribution)	T-distribution (with heavier tails)
# Formula
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# 𝑡
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝑠
# /
# 𝑛
# t=
# s/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Use Case	When σ is known or sample size is large	When σ is unknown and sample size is small

# %% [markdown]
# QUE-14  What is a confidence interval, and how is it used to interpret statistical results?
# ANS -
#
# A **confidence interval** (CI) is a range of values, derived from sample data, that is likely to contain the **true population parameter** (such as a mean, proportion, etc.) with a certain level of confidence. It provides an estimated range of values that is likely to include the population parameter based on the sample data.
#
# For example, a **95% confidence interval** means that if you were to take many samples and calculate their confidence intervals, about **95% of those intervals would contain the true population parameter**.
#
# ---
#
# ### ✅ **Key Components of a Confidence Interval**
#
# 1. **Point Estimate**: The sample statistic (e.g., sample mean, sample proportion).
# 2. **Margin of Error**: A value that accounts for variability in the sample, which is used to create the range of the confidence interval.
# 3. **Confidence Level**: The probability (often expressed as a percentage, such as 95% or 99%) that the interval contains the true population parameter.
#
# ---
#
# ### 🧠 **How Is a Confidence Interval Calculated?**
#
# The general formula for a confidence interval for a population mean when the population standard deviation ($\sigma$) is known is:
#
# $$
# \text{CI} = \bar{X} \pm Z_{\alpha/2} \left(\frac{\sigma}{\sqrt{n}}\right)
# $$
#
# Where:
#
# * $\bar{X}$ = sample mean
# * $Z_{\alpha/2}$ = Z-value corresponding to the desired confidence level (e.g., 1.96 for 95% CI)
# * $\sigma$ = population standard deviation (if known)
# * $n$ = sample size
#
# If the population standard deviation is **unknown**, and you're using a **T-test** (for small sample sizes), the formula adjusts slightly:
#
# $$
# \text{CI} = \bar{X} \pm t_{\alpha/2} \left(\frac{s}{\sqrt{n}}\right)
# $$
#
# Where:
#
# * $s$ = sample standard deviation
# * $t_{\alpha/2}$ = t-value from the t-distribution for the desired confidence level
#
# ---
#
# ### 🔍 **Interpreting a Confidence Interval**
#
# 1. **Range of Estimates**: The CI provides a **range** in which the true population parameter is likely to fall. For example, if the 95% confidence interval for a sample mean is \[45, 55], we can say that we are **95% confident** that the true population mean lies between 45 and 55.
#
# 2. **Confidence Level**: The **confidence level** (e.g., 95%) tells you how confident you can be that the interval includes the true parameter. If you have a 95% confidence level, it means that in 95% of repeated sampling, the intervals will capture the true population parameter.
#
# ---
#
# ### ⚖️ **What Does a Confidence Interval Tell You?**
#
# * **Precision of Estimates**: A narrow CI indicates that the sample mean is **precisely estimated**, while a wider CI suggests more **uncertainty**.
# * **Significance**: If a **hypothesized value** (such as 0 or a specific population mean) lies **outside the CI**, it suggests that the sample provides evidence against that value. For example, if a 95% CI for a population mean is \[10, 20], and the hypothesized population mean is 30, we would reject the hypothesis that the population mean is 30.

# %% [markdown]
# QUE-15 What is the margin of error, and how does it affect the confidence interval?
# ANS - 📘 What Is the Margin of Error?
# The margin of error (MoE) is the amount of error that is allowed in an estimate of a population parameter based on a sample. It provides a range around the sample estimate to reflect the uncertainty or variability in the estimate due to sampling. In other words, the margin of error indicates how much the sample estimate is expected to vary from the true population value.
#
# ✅ How Is the Margin of Error Calculated?
# The margin of error is typically calculated as:
#
# Margin of Error
# =
# 𝑍
# 𝛼
# /
# 2
# ×
# 𝜎
# 𝑛
# (for Z-test)
# Margin of Error=Z
# α/2
# ​
#  ×
# n
# ​
#
# σ
# ​
#  (for Z-test)
# OR
#
# Margin of Error
# =
# 𝑡
# 𝛼
# /
# 2
# ×
# 𝑠
# 𝑛
# (for T-test)
# Margin of Error=t
# α/2
# ​
#  ×
# n
# ​
#
# s
# ​
#  (for T-test)
# Where:
#
# 𝑍
# 𝛼
# /
# 2
# Z
# α/2
# ​
#   = Z-score for the desired confidence level (e.g., 1.96 for a 95% confidence level)
#
# 𝑡
# 𝛼
# /
# 2
# t
# α/2
# ​
#   = t-score for the desired confidence level (for small samples or unknown σ)
#
# 𝜎
# σ = population standard deviation (for Z-test)
#
# 𝑠
# s = sample standard deviation (for T-test)
#
# 𝑛
# n = sample size
#
# 🧠 How Does the Margin of Error Affect the Confidence Interval?
# The margin of error determines the width of the confidence interval (CI). A larger margin of error means a wider confidence interval, while a smaller margin of error results in a narrower interval. The confidence interval is calculated as:
#
# Confidence Interval
# =
# Sample Estimate
# ±
# Margin of Error
# Confidence Interval=Sample Estimate±Margin of Error
# Wider Interval: If the margin of error is larger, the confidence interval will be wider, suggesting more uncertainty in the estimate.
#
# Narrower Interval: A smaller margin of error will create a narrower confidence interval, indicating greater precision in the estimate.

# %% [markdown]
# QUE - 16 How is Bayes' Theorem used in statistics, and what is its significance?
# ANS - ### 📘 **What Is Bayes' Theorem in Statistics?**
#
# **Bayes' Theorem** is a fundamental concept in probability theory that allows you to update the probability of an event based on new evidence. It relates current evidence to prior knowledge, providing a way to revise our beliefs in light of new data.
#
# Bayes' Theorem is used in a variety of statistical applications, from hypothesis testing to machine learning and decision-making. It provides a formal way to combine **prior probabilities** (initial beliefs) with **likelihoods** (new data) to calculate **posterior probabilities** (updated beliefs).
#
# ---
#
# ### ✅ **Bayes' Theorem Formula**
#
# Bayes' Theorem is expressed as:
#
# $$
# P(A | B) = \frac{P(B | A) P(A)}{P(B)}
# $$
#
# Where:
#
# * **$P(A | B)$** is the **posterior probability** — the probability of event **A** happening given that **B** has occurred.
# * **$P(B | A)$** is the **likelihood** — the probability of observing **B** given that **A** is true.
# * **$P(A)$** is the **prior probability** — the initial probability of event **A** before seeing the new evidence.
# * **$P(B)$** is the **marginal likelihood** — the probability of observing the evidence **B**, which can be found using the law of total probability.
#
# ---
#
# ### 🧠 **How Does Bayes' Theorem Work?**
#
# Bayes' Theorem allows you to **update your beliefs** about the probability of an event as new information or evidence is acquired.
#
# 1. **Prior Probability** ($P(A)$): Initially, we start with a belief about the probability of an event based on previous knowledge or data.
# 2. **Likelihood** ($P(B | A)$): We obtain new evidence (e.g., an observation or experiment), and the likelihood is how probable this new evidence is, assuming the event $A$ is true.
# 3. **Posterior Probability** ($P(A | B)$): Using Bayes' Theorem, we calculate the updated probability of event $A$ considering both the prior knowledge and the new evidence.
#
#
#
# ---
#
# ### 🧩 **Significance of Bayes' Theorem in Statistics**
#
# 1. **Updating Beliefs**: Bayes' Theorem allows you to **revise** your beliefs based on new data. It is particularly useful in situations where information evolves over time, such as in medical diagnostics, stock market analysis, or machine learning.
#
# 2. **Incorporating Prior Knowledge**: Unlike frequentist statistics, which only uses the data at hand, Bayes' Theorem allows for the **incorporation of prior knowledge** or **historical data** into the analysis. This is useful when the available sample size is small or when we have reliable information from previous studies or experiments.
#
# 3. **Probabilistic Inference**: It provides a framework for making **probabilistic inferences** about unknown quantities. For example, in hypothesis testing, Bayes' Theorem allows you to update the probability of a hypothesis being true based on the observed data, instead of relying on a fixed significance threshold (like p-values).
#
# 4. **Decision Making Under Uncertainty**: Bayes' Theorem helps in decision-making when there is uncertainty. By combining prior beliefs with evidence, it enables you to make informed decisions with more certainty, especially when there are multiple possible outcomes.
#
# 5. **Applications in Machine Learning**: In **machine learning**, particularly in **Bayesian networks** and **Bayesian inference**, Bayes' Theorem is used for tasks like **classification**, **regression**, and **model selection**, where updating probabilities is key to refining models over time.
#
# -

# %% [markdown]
# QUE-17  What is the Chi-square distribution, and when is it used?
# ANS - The Chi-square distribution (often denoted as
# 𝜒
# 2
# χ
# 2
#  ) is a probability distribution that is widely used in statistical hypothesis testing, particularly when dealing with categorical data. It is a continuous distribution that is derived from the sum of the squares of independent standard normal variables.
#
# Mathematically, if
# 𝑍
# 1
# ,
# 𝑍
# 2
# ,
# …
# ,
# 𝑍
# 𝑘
# Z
# 1
# ​
#  ,Z
# 2
# ​
#  ,…,Z
# k
# ​
#   are independent standard normal random variables, then the sum of their squares:
#
# 𝑋
# 2
# =
# 𝑍
# 1
# 2
# +
# 𝑍
# 2
# 2
# +
# ⋯
# +
# 𝑍
# 𝑘
# 2
# X
# 2
#  =Z
# 1
# 2
# ​
#  +Z
# 2
# 2
# ​
#  +⋯+Z
# k
# 2
# ​
#
# follows a Chi-square distribution with k degrees of freedom. The degrees of freedom typically represent the number of independent pieces of information used in the calculation.
#
# ✅ Key Properties of the Chi-Square Distribution:
# Non-Negative: The Chi-square distribution is defined only for non-negative values of
# 𝑋
# 2
# X
# 2
#  , meaning it only takes values greater than or equal to 0.
#
# Skewed Right: The Chi-square distribution is positively skewed (right-skewed), particularly when the degrees of freedom are small. As the degrees of freedom increase, the distribution becomes more symmetric and approaches a normal distribution.
#
# Mean and Variance:
#
# Mean of a Chi-square distribution:
# 𝜇
# =
# 𝑘
# μ=k, where
# 𝑘
# k is the degrees of freedom.
#
# Variance:
# 𝜎
# 2
# =
# 2
# 𝑘
# σ
# 2
#  =2k.
#
# 🎯 When Is the Chi-Square Distribution Used?
# The Chi-square distribution is used in several key statistical methods, including:
#
# Chi-Square Goodness-of-Fit Test:
#
# Purpose: This test is used to determine whether a sample data fits a specified distribution. It compares the observed frequencies with the expected frequencies under a certain hypothesis.
#
# Application: For example, you might use it to test if a die is fair by comparing the observed frequencies of rolling each number with the expected frequencies.
#
# Test Statistic: The test statistic for this test is:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# 𝑖
# −
# 𝐸
# 𝑖
# )
# 2
# 𝐸
# 𝑖
# χ
# 2
#  =∑
# E
# i
# ​
#
# (O
# i
# ​
#  −E
# i
# ​
#  )
# 2
#
# ​
#
# where
# 𝑂
# 𝑖
# O
# i
# ​
#   is the observed frequency, and
# 𝐸
# 𝑖
# E
# i
# ​
#   is the expected frequency for the
# 𝑖
# i-th category.
#
# Chi-Square Test of Independence:
#
# Purpose: This test assesses whether two categorical variables are independent or if there is an association between them. It compares the observed frequencies in a contingency table to the expected frequencies under the assumption of independence.
#
# Application: For example, testing whether gender is independent of voting preference, where you collect data on gender and voting choice, then check if the two variables are independent.
#
# Test Statistic: The formula for the test statistic is:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# 𝑖
# 𝑗
# −
# 𝐸
# 𝑖
# 𝑗
# )
# 2
# 𝐸
# 𝑖
# 𝑗
# χ
# 2
#  =∑
# E
# ij
# ​
#
# (O
# ij
# ​
#  −E
# ij
# ​
#  )
# 2
#
# ​
#
# where
# 𝑂
# 𝑖
# 𝑗
# O
# ij
# ​
#   is the observed frequency in the
# 𝑖
# i-th row and
# 𝑗
# j-th column of the contingency table, and
# 𝐸
# 𝑖
# 𝑗
# E
# ij
# ​
#   is the expected frequency.

# %% [markdown]
# QUE 18 What is the Chi-square goodness of fit test, and how is it applied?
# ANS - The Chi-square goodness-of-fit test is a statistical test used to determine how well an observed distribution of categorical data matches an expected distribution. It is typically used to assess whether the frequencies of data in different categories align with what we would expect under a specific hypothesis (often called the "null hypothesis").
#
# The null hypothesis typically states that there is no significant difference between the observed and expected frequencies, meaning the data follows the expected distribution. The alternative hypothesis, on the other hand, suggests that the observed frequencies significantly differ from the expected frequencies.
#
# ✅ How Is the Chi-Square Goodness-of-Fit Test Applied?
# 1. Set up the Hypotheses:
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): The observed frequencies follow the expected distribution.
#
# Alternative Hypothesis (
# 𝐻
# 𝐴
# H
# A
# ​
#  ): The observed frequencies do not follow the expected distribution.
#
# 2. Calculate the Test Statistic:
# The test statistic for the Chi-square goodness-of-fit test is:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# 𝑖
# −
# 𝐸
# 𝑖
# )
# 2
# 𝐸
# 𝑖
# χ
# 2
#  =∑
# E
# i
# ​
#
# (O
# i
# ​
#  −E
# i
# ​
#  )
# 2
#
# ​
#
# Where:
#
# 𝑂
# 𝑖
# O
# i
# ​
#   = Observed frequency for category
# 𝑖
# i
#
# 𝐸
# 𝑖
# E
# i
# ​
#   = Expected frequency for category
# 𝑖
# i
#
# This formula sums the squared differences between the observed and expected frequencies, divided by the expected frequency for each category.
#
# 3. Determine Degrees of Freedom (df):
# The degrees of freedom for the Chi-square goodness-of-fit test is calculated as:
#
# 𝑑
# 𝑓
# =
# 𝑘
# −
# 1
# df=k−1
# Where:
#
# 𝑘
# k = Number of categories (or levels) in the categorical variable.
#
# 4. Find the Critical Value:
# Using the degrees of freedom and a chosen significance level (often
# 𝛼
# =
# 0.05
# α=0.05), find the critical value from the Chi-square distribution table.
#
# 5. Compare the Test Statistic to the Critical Value:
# If the test statistic
# 𝜒
# 2
# χ
# 2
#   is greater than the critical value from the table, reject the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ).
#
# If the test statistic
# 𝜒
# 2
# χ
# 2
#   is less than or equal to the critical value, fail to reject the null hypothesis.

# %% [markdown]
# QUE-19 What is the F-distribution, and when is it used in hypothesis testing?
# ANS - The F-distribution is a continuous probability distribution that arises in the context of hypothesis testing, particularly when comparing variances across groups. It is a ratio of two independent Chi-square distributions, each divided by their respective degrees of freedom. The F-distribution is primarily used in the analysis of variance (ANOVA) and in the testing of hypotheses about the variances of populations.
#
# Formula for the F-Statistic:
# The F-statistic is calculated as the ratio of two sample variances, each divided by their respective degrees of freedom:
#
# 𝐹
# =
# 𝑠
# 1
# 2
# /
# 𝑑
# 𝑓
# 1
# 𝑠
# 2
# 2
# /
# 𝑑
# 𝑓
# 2
# F=
# s
# 2
# 2
# ​
#  /df
# 2
# ​
#
# s
# 1
# 2
# ​
#  /df
# 1
# ​
#
# ​
#
# Where:
#
# 𝑠
# 1
# 2
# s
# 1
# 2
# ​
#   and
# 𝑠
# 2
# 2
# s
# 2
# 2
# ​
#   are the sample variances.
#
# 𝑑
# 𝑓
# 1
# df
# 1
# ​
#   and
# 𝑑
# 𝑓
# 2
# df
# 2
# ​
#   are the degrees of freedom of the two samples.
#
# ✅ Key Properties of the F-Distribution:
# Non-Negative: The F-distribution takes only positive values, meaning
# 𝐹
# ≥
# 0
# F≥0.
#
# Skewed Right: The F-distribution is right-skewed with a long tail towards the right. As the degrees of freedom increase, the distribution becomes more symmetric and approaches a normal distribution.
#
# Two Parameters: The F-distribution is defined by two parameters:
#
# 𝑑
# 𝑓
# 1
# df
# 1
# ​
#   (degrees of freedom for the numerator)
#
# 𝑑
# 𝑓
# 2
# df
# 2
# ​
#   (degrees of freedom for the denominator)
#
# Mean and Variance:
#
# The mean of an F-distribution is given by
# 𝑑
# 𝑓
# 2
# 𝑑
# 𝑓
# 2
# −
# 2
# df
# 2
# ​
#  −2
# df
# 2
# ​
#
# ​
#   for
# 𝑑
# 𝑓
# 2
# >
# 2
# df
# 2
# ​
#  >2.
#
# The variance is
# 2
# (
# 𝑑
# 𝑓
# 2
# )
# 2
# (
# 𝑑
# 𝑓
# 1
# +
# 1
# )
# 𝑑
# 𝑓
# 1
# (
# 𝑑
# 𝑓
# 2
# −
# 2
# )
# 2
# (
# 𝑑
# 𝑓
# 2
# −
# 4
# )
# df
# 1
# ​
#  (df
# 2
# ​
#  −2)
# 2
#  (df
# 2
# ​
#  −4)
# 2(df
# 2
# ​
#  )
# 2
#  (df
# 1
# ​
#  +1)
# ​
#  , for
# 𝑑
# 𝑓
# 2
# >
# 4
# df
# 2
# ​
#  >4.
#
# 🎯 When is the F-Distribution Used in Hypothesis Testing?
# The F-distribution is used in several key areas of hypothesis testing:
#
# 1. Analysis of Variance (ANOVA):
# Purpose: The most common use of the F-distribution is in Analysis of Variance (ANOVA), which is used to test whether there are significant differences between the means of three or more groups.
#
# F-statistic in ANOVA: The F-statistic is the ratio of two variances:
#
# 𝐹
# =
# variance between group means
# variance within groups
# F=
# variance within groups
# variance between group means
# ​
#
# If the null hypothesis is true (i.e., all group means are equal), the between-group variance should be approximately equal to the within-group variance, and the F-statistic will be close to 1. If the F-statistic is large, it suggests that the means of the groups are different.
#
# 2. Testing the Equality of Variances:
# Purpose: The F-distribution is used to test if the variances of two populations are equal. This is important in many statistical methods, such as t-tests, where the assumption of equal variances is often made.
#
# F-Test for Equality of Variances: If you have two independent samples and you want to test whether their variances are equal, you can compute the F-statistic as the ratio of their sample variances. If the two variances are equal, the F-statistic will be close to 1. A large or small F-statistic suggests that the variances are different.
#
# Null hypothesis:
# 𝜎
# 1
# 2
# =
# 𝜎
# 2
# 2
# σ
# 1
# 2
# ​
#  =σ
# 2
# 2
# ​
#   (the variances are equal).
#
# Alternative hypothesis:
# 𝜎
# 1
# 2
# ≠
# 𝜎
# 2
# 2
# σ
# 1
# 2
# ​
#
# 
# =σ
# 2
# 2
# ​
#   (the variances are different).
#
# 3. Regression Analysis:
# Purpose: In multiple regression analysis, the F-distribution is used to test the overall significance of the regression model.
#
# F-Test in Regression: The F-test is used to assess whether at least one of the predictor variables in a regression model has a non-zero coefficient. It is based on the ratio of explained variance to unexplained variance. A large F-statistic suggests that the regression model fits the data well.
#
# 4. Comparing More Than Two Models:
# Purpose: The F-distribution is used to compare the fit of two or more statistical models. For example, in the context of nested models (where one model is a subset of another), the F-test can help determine whether adding more predictors improves the model significantly.

# %% [markdown]
# QUE-20 What is an ANOVA test, and what are its assumptions?
# ANS - ANOVA (Analysis of Variance) is a statistical test used to compare the means of three or more groups to determine if there are statistically significant differences between them. The primary goal of ANOVA is to assess whether any of the group means differ from each other, based on sample data.
#
# ANOVA tests the null hypothesis that all group means are equal, and the alternative hypothesis that at least one group mean is different.
#
# Basic Idea:
# ANOVA works by comparing the variance within groups to the variance between groups. If the variance between the groups is significantly larger than the variance within the groups, it suggests that the group means are not all equal.
#
# 🎯 Assumptions of ANOVA
# For the results of an ANOVA test to be valid, several assumptions need to be met:
#
# Independence of Observations:
#
# The observations in each group must be independent of each other. This means that the data points in one group should not influence the data points in another group.
#
# Normality:
#
# The data in each group should be approximately normally distributed. This assumption ensures that the F-statistic follows the correct distribution under the null hypothesis. If the sample sizes are large, the Central Limit Theorem can help mitigate this assumption.
#
# Homogeneity of Variance (Homogeneity of Variances):
#
# The variances of the groups being compared should be approximately equal. This assumption is important because the F-statistic is sensitive to differences in group variances. This is sometimes tested using Levene's Test or Bartlett’s Test for homogeneity of variances.
#
# Random Sampling:
#
# The data should come from random samples. This ensures that the results are generalizable and not biased by the method of data collection.

# %% [markdown]
# QUE-21 What are the different types of ANOVA tests?
# ANS - There are several types of ANOVA tests, depending on the design of the study:
#
# One-Way ANOVA:
#
# Used when you have one independent variable with three or more levels (groups).
#
# Example: Comparing the exam scores of students from three different teaching methods (Method A, B, and C).
#
# Two-Way ANOVA:
#
# Used when you have two independent variables and you want to examine their individual and interactive effects on the dependent variable.
#
# Example: Studying how both teaching method and gender (male, female) affect student performance.
#
# Repeated Measures ANOVA:
#
# Used when the same subjects are measured multiple times under different conditions, or across different time points.
#
# Example: Testing how patients' blood pressure changes over time after taking three different medications.

# %% [markdown]
# QUE-22 What is the F-test, and how does it relate to hypothesis testing?
# ANS - The F-test is a statistical test used to compare the variances of two or more groups or to test the overall significance of a regression model. The F-test is based on the F-distribution, which is the ratio of two variances. It is primarily used in ANOVA (Analysis of Variance) and in the context of comparing the goodness of fit of models, particularly in regression analysis.
#
# The F-test essentially answers the question:
# Are the variances of two or more groups significantly different from each other?
#
# 🎯 Hypotheses in the F-Test
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): In ANOVA, the null hypothesis states that all group means are equal. In regression, it states that the regression model does not significantly explain the variance in the dependent variable.
#
# 𝐻
# 0
# :
# 𝜇
# 1
# =
# 𝜇
# 2
# =
# 𝜇
# 3
# =
# ⋯
# =
# 𝜇
# 𝑘
# H
# 0
# ​
#  :μ
# 1
# ​
#  =μ
# 2
# ​
#  =μ
# 3
# ​
#  =⋯=μ
# k
# ​
#
# In regression:
#
# 𝐻
# 0
# :
# All regression coefficients are zero (no relationship between predictors and the outcome)
# H
# 0
# ​
#  :All regression coefficients are zero (no relationship between predictors and the outcome)
# Alternative Hypothesis (
# 𝐻
# 𝐴
# H
# A
# ​
#  ): In ANOVA, the alternative hypothesis suggests that at least one group mean is different from the others. In regression, it suggests that at least one regression coefficient is non-zero (there is some relationship between the predictors and the outcome).
#
# 𝐻
# 𝐴
# :
# At least one group mean is different.
# H
# A
# ​
#  :At least one group mean is different.
# In regression:
#
# 𝐻
# 𝐴
# :
# At least one regression coefficient is non-zero.
# H
# A
# ​
#  :At least one regression coefficient is non-zero.

# %% [markdown]
# Practical Part - 2

# %%
#QUE-1 Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
#interpret the results.
#ANS -
from statsmodels.stats.weightstats import ztest as ztest

def perform_z_test(sample_data, population_mean, alpha=0.05):
  """
  Performs a one-sample Z-test to compare a sample mean to a known population mean.

  Args:
    sample_data: A list or array of sample data.
    population_mean: The known mean of the population.
    alpha: The significance level (default is 0.05).

  Returns:
    A tuple containing the z-statistic and the p-value.
  """
  # Perform the Z-test
  z_statistic, p_value = ztest(x1=sample_data, value=population_mean)

  # Interpret the results
  print(f"Z-statistic: {z_statistic:.4f}")
  print(f"P-value: {p_value:.4f}")

  if p_value < alpha:
    print(f"At the {alpha} significance level, we reject the null hypothesis.")
    print("There is sufficient evidence to conclude that the sample mean is significantly different from the population mean.")
  else:
    print(f"At the {alpha} significance level, we fail to reject the null hypothesis.")
    print("There is not sufficient evidence to conclude that the sample mean is significantly different from the population mean.")

  return z_statistic, p_value

# Example usage:
# Assume we have a sample of test scores and a known population mean for those scores.
sample_scores = [75, 80, 85, 90, 95, 78, 88, 92, 83, 87]
known_population_mean = 80

perform_z_test(sample_scores, known_population_mean)
# Out:
# Z-statistic: 2.6350
# P-value: 0.0084
# At the 0.05 significance level, we reject the null hypothesis.
# There is sufficient evidence to conclude that the sample mean is significantly different from the population mean.
# (np.float64(2.6350374070922795), np.float64(0.008412801121727327))

# %%
#QUE-2  Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python?
#ANS-

import numpy as np
# Simulate random data (e.g., a sample from a normal distribution)
# You can adjust the mean, standard deviation, and sample size as needed.
sample_mean = 85
sample_std_dev = 10
sample_size = 50

simulated_data = np.random.normal(loc=sample_mean, scale=sample_std_dev, size=sample_size)

# Define the population mean to test against
population_mean_hypothesis = 80

# Perform the Z-test and get the P-value
z_stat, p_value = perform_z_test(simulated_data, population_mean_hypothesis)

print("\nSimulation Results:")
print(f"Simulated Sample Mean: {np.mean(simulated_data):.4f}")
print(f"Hypothesized Population Mean: {population_mean_hypothesis}")
print(f"Z-statistic from simulation: {z_stat:.4f}")
print(f"P-value from simulation: {p_value:.4f}")
# Out:
# Z-statistic: 4.0232
# P-value: 0.0001
# At the 0.05 significance level, we reject the null hypothesis.
# There is sufficient evidence to conclude that the sample mean is significantly different from the population mean.
#
# Simulation Results:
# Simulated Sample Mean: 85.6826
# Hypothesized Population Mean: 80
# Z-statistic from simulation: 4.0232
# P-value from simulation: 0.0001

# %%
#QUE-3  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
#ANS-

import numpy as np
# Additional example with different data
sample_salaries = [55000, 60000, 62000, 58000, 70000, 65000, 68000]
known_population_salary_mean = 63000

print("\nAdditional Example (Salaries):")
perform_z_test(sample_salaries, known_population_salary_mean, alpha=0.10)

# Another simulated example with a different population mean
simulated_data_2 = np.random.normal(loc=75, scale=12, size=60)
population_mean_hypothesis_2 = 78

print("\nAnother Simulation:")
z_stat_2, p_value_2 = perform_z_test(simulated_data_2, population_mean_hypothesis_2)

print("\nAnother Simulation Results:")
print(f"Simulated Sample Mean: {np.mean(simulated_data_2):.4f}")
print(f"Hypothesized Population Mean: {population_mean_hypothesis_2}")
print(f"Z-statistic from simulation: {z_stat_2:.4f}")
print(f"P-value from simulation: {p_value_2:.4f}")
# Out:
# Additional Example (Salaries):
# Z-statistic: -0.2095
# P-value: 0.8340
# At the 0.1 significance level, we fail to reject the null hypothesis.
# There is not sufficient evidence to conclude that the sample mean is significantly different from the population mean.
#
# Another Simulation:
# Z-statistic: -3.3520
# P-value: 0.0008
# At the 0.05 significance level, we reject the null hypothesis.
# There is sufficient evidence to conclude that the sample mean is significantly different from the population mean.
#
# Another Simulation Results:
# Simulated Sample Mean: 73.1062
# Hypothesized Population Mean: 78
# Z-statistic from simulation: -3.3520
# P-value from simulation: 0.0008

# %%
 #QUE-4  Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# The previous code already includes the Z-test function and plotting.
# This cell focuses on performing the Z-test and then plotting the decision regions.

# Define sample data and population mean
sample_data_for_plot = np.random.normal(loc=70, scale=15, size=100)
population_mean_for_plot = 75
alpha_for_plot = 0.05 # Significance level for the two-tailed test

# Perform the Z-test
z_stat_plot, p_value_plot = ztest(x1=sample_data_for_plot, value=population_mean_for_plot)

print(f"Z-statistic for plot: {z_stat_plot:.4f}")
print(f"P-value for plot: {p_value_plot:.4f}")

# Plot the Z-distribution and decision regions
z_critical_lower_plot = norm.ppf(alpha_for_plot / 2)
z_critical_upper_plot = norm.ppf(1 - alpha_for_plot / 2)

x_plot = np.linspace(-4, 4, 1000)
y_plot = norm.pdf(x_plot)

plt.figure(figsize=(10, 6))
plt.plot(x_plot, y_plot, label='Standard Normal Distribution (Z-distribution)')

# Shade the rejection regions
plt.fill_between(x_plot, y_plot, where=(x_plot <= z_critical_lower_plot), color='red', alpha=0.3, label='Rejection Region')
plt.fill_between(x_plot, y_plot, where=(x_plot >= z_critical_upper_plot), color='red', alpha=0.3)

# Shade the acceptance region
plt.fill_between(x_plot, y_plot, where=(x_plot > z_critical_lower_plot) & (x_plot < z_critical_upper_plot), color='green', alpha=0.3, label='Acceptance Region')

# Mark the calculated Z-statistic
plt.axvline(z_stat_plot, color='blue', linestyle='dashed', linewidth=2, label=f'Calculated Z-statistic: {z_stat_plot:.4f}')

plt.title('Two-Tailed Z-Test Decision Regions')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-statistic for plot: -2.1989
# P-value for plot: 0.0279

# %%
# QUE-5 Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

import matplotlib.pyplot as plt
import numpy as np
def plot_type1_type2_errors(mu_null, mu_alt, sigma, n, alpha):
  """
  Calculates and visualizes Type 1 and Type 2 errors for a one-tailed Z-test.

  Args:
    mu_null: Population mean under the null hypothesis.
    mu_alt: Population mean under the alternative hypothesis (for Type 2 error calculation).
    sigma: Population standard deviation.
    n: Sample size.
    alpha: Significance level (probability of Type 1 error).
  """
  # Standard error
  se = sigma / np.sqrt(n)

  # Calculate critical value for a right-tailed test (assuming Ha > mu_null)
  # You can adjust for a left-tailed test by using norm.ppf(alpha)
  z_critical = norm.ppf(1 - alpha)
  x_critical = mu_null + z_critical * se

  # Calculate beta (probability of Type 2 error) for a right-tailed test
  # Beta is the probability of failing to reject H0 when H1 is true
  # This is the area under the alternative distribution to the left of the critical value
  z_beta = (x_critical - mu_alt) / se
  beta = norm.cdf(z_beta)

  # Power of the test (1 - beta)
  power = 1 - beta

  print(f"Type 1 Error (alpha): {alpha:.4f}")
  print(f"Type 2 Error (beta): {beta:.4f}")
  print(f"Power (1 - beta): {power:.4f}")

  # Visualize the errors
  x = np.linspace(mu_null - 4 * se, mu_alt + 4 * se, 1000)

  plt.figure(figsize=(12, 7))

  # Plot the null distribution
  y_null = norm.pdf(x, mu_null, se)
  plt.plot(x, y_null, label=f'Null Hypothesis (H0: μ = {mu_null})', color='blue')
  plt.fill_between(x, y_null, where=(x >= x_critical), color='red', alpha=0.3, label=f'Type 1 Error (α={alpha:.2f})')

  # Plot the alternative distribution
  y_alt = norm.pdf(x, mu_alt, se)
  plt.plot(x, y_alt, label=f'Alternative Hypothesis (Ha: μ = {mu_alt})', color='green')
  plt.fill_between(x, y_alt, where=(x < x_critical), color='orange', alpha=0.3, label=f'Type 2 Error (β={beta:.2f})')

  # Plot the critical value
  plt.axvline(x_critical, color='black', linestyle='dashed', linewidth=1.5, label=f'Critical Value ({x_critical:.2f})')

  plt.title('Type 1 and Type 2 Errors Visualization (Right-Tailed Test)')
  plt.xlabel('Sample Mean')
  plt.ylabel('Probability Density')
  plt.legend()
  plt.grid(True)
  plt.show()

# Example Usage:
# Assume we are testing if the mean score of a new teaching method (Ha) is greater than the standard method (H0).
# Population mean under H0: 75
# Population mean under Ha: 78 (assuming a true effect size)
# Population standard deviation: 10
# Sample size: 30
# Significance level: 0.05

mu_null_example = 75
mu_alt_example = 78
sigma_example = 10
n_example = 30
alpha_example = 0.05

plot_type1_type2_errors(mu_null_example, mu_alt_example, sigma_example, n_example, alpha_example)

# Another example with different parameters
mu_null_example_2 = 100
mu_alt_example_2 = 105
sigma_example_2 = 15
n_example_2 = 50
alpha_example_2 = 0.01

plot_type1_type2_errors(mu_null_example_2, mu_alt_example_2, sigma_example_2, n_example_2, alpha_example_2)
# Out:
# Type 1 Error (alpha): 0.0500
# Type 2 Error (beta): 0.5007
# Power (1 - beta): 0.4993
# Type 1 Error (alpha): 0.0100
# Type 2 Error (beta): 0.4878
# Power (1 - beta): 0.5122

# %%
# QUE-6: Write a Python program to perform an independent T-test and interpret the results.

from scipy.stats import ttest_ind
import numpy as np

def perform_independent_t_test(sample1_data, sample2_data, alpha=0.05):
  """
  Performs an independent samples T-test and interprets the results.

  Args:
    sample1_data: A list or array of data from the first sample.
    sample2_data: A list or array of data from the second sample.
    alpha: The significance level (default is 0.05).

  Returns:
    A tuple containing the t-statistic and the p-value.
  """
  # Perform the independent T-test
  # equal_var=True assumes equal variances between the two samples.
  # If variances are not assumed to be equal, set equal_var=False (Welch's T-test)
  t_statistic, p_value = ttest_ind(a=sample1_data, b=sample2_data, equal_var=True)

  # Interpret the results
  print(f"Independent Samples T-test Results:")
  print(f"T-statistic: {t_statistic:.4f}")
  print(f"P-value: {p_value:.4f}")

  if p_value < alpha:
    print(f"At the {alpha} significance level, we reject the null hypothesis.")
    print("There is sufficient evidence to conclude that the means of the two samples are significantly different.")
  else:
    print(f"At the {alpha} significance level, we fail to reject the null hypothesis.")
    print("There is not sufficient evidence to conclude that the means of the two samples are significantly different.")

  return t_statistic, p_value

# Example Usage:
# Assume we have test scores from two different groups of students.
group1_scores = [85, 90, 78, 92, 88, 75, 80, 83, 87, 95]
group2_scores = [70, 75, 80, 85, 72, 78, 83, 88, 76, 81]

perform_independent_t_test(group1_scores, group2_scores)

# Another example with simulated data
simulated_group1 = np.random.normal(loc=60, scale=10, size=30)
simulated_group2 = np.random.normal(loc=65, scale=10, size=30)

print("\nAnother Example (Simulated Data):")
perform_independent_t_test(simulated_group1, simulated_group2, alpha=0.01)
# Out:
# Independent Samples T-test Results:
# T-statistic: 2.4045
# P-value: 0.0272
# At the 0.05 significance level, we reject the null hypothesis.
# There is sufficient evidence to conclude that the means of the two samples are significantly different.
#
# Another Example (Simulated Data):
# Independent Samples T-test Results:
# T-statistic: -1.2886
# P-value: 0.2027
# At the 0.01 significance level, we fail to reject the null hypothesis.
# There is not sufficient evidence to conclude that the means of the two samples are significantly different.
# (np.float64(-1.2885885259790177), np.float64(0.20265765054263535))

# %%
# QUE-7: Perform a paired sample T-test using Python and visualize the comparison results.
#ANS-
from scipy.stats import ttest_rel
import matplotlib.pyplot as plt
import numpy as np

def perform_paired_t_test_and_visualize(before_data, after_data, alpha=0.05):
  """
  Performs a paired samples T-test, interprets the results, and visualizes the comparison.

  Args:
    before_data: A list or array of data from the 'before' condition.
    after_data: A list or array of data from the 'after' condition.
    alpha: The significance level (default is 0.05).
  """
  if len(before_data) != len(after_data):
    print("Error: The lengths of 'before' and 'after' data must be the same for a paired T-test.")
    return

  # Perform the paired T-test
  # The null hypothesis is that the mean difference between the pairs is zero.
  t_statistic, p_value = ttest_rel(a=before_data, b=after_data)

  # Interpret the results
  print(f"Paired Samples T-test Results:")
  print(f"T-statistic: {t_statistic:.4f}")
  print(f"P-value: {p_value:.4f}")

  if p_value < alpha:
    print(f"At the {alpha} significance level, we reject the null hypothesis.")
    print("There is sufficient evidence to conclude that there is a significant difference between the 'before' and 'after' measurements.")
  else:
    print(f"At the {alpha} significance level, we fail to reject the null hypothesis.")
    print("There is not sufficient evidence to conclude that there is a significant difference between the 'before' and 'after' measurements.")

  # Visualize the results
  plt.figure(figsize=(10, 6))

  # Plot individual paired data points
  for i in range(len(before_data)):
    plt.plot([1, 2], [before_data[i], after_data[i]], marker='o', linestyle='-', color='gray', alpha=0.5)

  # Plot the average of the 'before' and 'after' groups
  avg_before = np.mean(before_data)
  avg_after = np.mean(after_data)
  plt.plot([1, 2], [avg_before, avg_after], marker='o', linestyle='--', color='blue', linewidth=2, label=f'Average (Before: {avg_before:.2f}, After: {avg_after:.2f})')

  plt.xticks([1, 2], ['Before', 'After'])
  plt.ylabel('Measurement Value')
  plt.title('Paired Samples Comparison')
  plt.legend()
  plt.grid(True)
  plt.show()

# Example Usage:
# Assume we measure the blood pressure of a group of patients before and after a treatment.
blood_pressure_before = [145, 150, 140, 155, 160, 148, 152, 158]
blood_pressure_after = [138, 142, 135, 148, 155, 140, 145, 150]

perform_paired_t_test_and_visualize(blood_pressure_before, blood_pressure_after)

# Another example with simulated data (e.g., performance scores before and after training)
scores_before_training = np.random.normal(loc=70, scale=5, size=20)
scores_after_training = scores_before_training + np.random.normal(loc=3, scale=2, size=20) # Simulate an increase

print("\nAnother Example (Simulated Training Scores):")
perform_paired_t_test_and_visualize(scores_before_training, scores_after_training, alpha=0.01)
# Out:
# Paired Samples T-test Results:
# T-statistic: 15.6010
# P-value: 0.0000
# At the 0.05 significance level, we reject the null hypothesis.
# There is sufficient evidence to conclude that there is a significant difference between the 'before' and 'after' measurements.
# Another Example (Simulated Training Scores):
# Paired Samples T-test Results:
# T-statistic: -4.1410
# P-value: 0.0006
# At the 0.01 significance level, we reject the null hypothesis.
# There is sufficient evidence to conclude that there is a significant difference between the 'before' and 'after' measurements.

# %%
# QUE-8:  Simulate data and perform both Z-test and T-test, then compare the results using Python.
#ANS-
import numpy as np
# Simulate two datasets
# Dataset 1: Represents sample data
np.random.seed(42)  # for reproducibility
sample_data = np.random.normal(loc=75, scale=10, size=50)

# Dataset 2: Represents another sample data for comparison (independent t-test)
sample_data_2 = np.random.normal(loc=78, scale=12, size=60)

# Assume a known population mean for the Z-test
population_mean_z_test = 70

print("Performing Z-test (comparing sample_data to population_mean_z_test):")
z_stat, p_value_z = ztest(x1=sample_data, value=population_mean_z_test)
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value (Z-test): {p_value_z:.4f}")

alpha = 0.05
if p_value_z < alpha:
  print("Z-test Conclusion: Reject the null hypothesis. The sample mean is significantly different from the hypothesized population mean.")
else:
  print("Z-test Conclusion: Fail to reject the null hypothesis. There is no significant difference from the hypothesized population mean.")

print("\nPerforming Independent T-test (comparing sample_data and sample_data_2):")
t_stat, p_value_t = ttest_ind(sample_data, sample_data_2)
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value (T-test): {p_value_t:.4f}")

if p_value_t < alpha:
  print("T-test Conclusion: Reject the null hypothesis. The means of the two independent samples are significantly different.")
else:
  print("T-test Conclusion: Fail to reject the null hypothesis. There is no significant difference between the means of the two independent samples.")

print("\nComparison of Results:")
print(f"Z-test P-value: {p_value_z:.4f}")
print(f"T-test P-value: {p_value_t:.4f}")

# Note: In this specific simulation, the Z-test uses a known population mean,
# while the T-test compares the means of two samples. The p-values might differ
# based on the simulated data and the hypothesis being tested in each case.
# The Z-test is generally used when the population standard deviation is known
# and/or the sample size is large, while the T-test is used when the population
# standard deviation is unknown, especially for smaller sample sizes.
# Here, we simulated data appropriate for both tests in their respective contexts.
# Out:
# Performing Z-test (comparing sample_data to population_mean_z_test):
# Z-statistic: 2.0791
# P-value (Z-test): 0.0376
# Z-test Conclusion: Reject the null hypothesis. The sample mean is significantly different from the hypothesized population mean.
#
# Performing Independent T-test (comparing sample_data and sample_data_2):
# T-statistic: -2.8056
# P-value (T-test): 0.0060
# T-test Conclusion: Reject the null hypothesis. The means of the two independent samples are significantly different.
#
# Comparison of Results:
# Z-test P-value: 0.0376
# T-test P-value: 0.0060

# %%
# QUE-9: Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
#ANS-
import numpy as np
from scipy.stats import norm, t

def calculate_confidence_interval_mean(data, confidence_level=0.95, assumed_pop_std=None):
  """
  Calculates the confidence interval for a sample mean.

  Args:
    data: A list or array of numerical data.
    confidence_level: The desired confidence level (e.g., 0.95 for 95%).
    assumed_pop_std: The known population standard deviation.
                     If None (default), the sample standard deviation is used,
                     and a t-distribution is used.

  Returns:
    A tuple containing the lower and upper bounds of the confidence interval.
    Returns None if the data is empty.
  """
  if not data:
    print("Error: Input data is empty.")
    return None

  sample_mean = np.mean(data)
  sample_size = len(data)

  alpha = 1 - confidence_level

  if assumed_pop_std is not None:
    # Use Z-distribution if population standard deviation is known
    print("Using Z-distribution (assumed population standard deviation is known)")
    standard_error = assumed_pop_std / np.sqrt(sample_size)
    z_critical = norm.ppf(1 - alpha / 2)
    margin_of_error = z_critical * standard_error
  else:
    # Use T-distribution if population standard deviation is unknown
    print("Using T-distribution (population standard deviation is unknown)")
    if sample_size < 2:
        print("Error: Sample size must be at least 2 for T-distribution.")
        return None
    sample_std = np.std(data, ddof=1) # Use sample standard deviation (ddof=1 for unbiased estimate)
    standard_error = sample_std / np.sqrt(sample_size)
    degrees_of_freedom = sample_size - 1
    t_critical = t.ppf(1 - alpha / 2, degrees_of_freedom)
    margin_of_error = t_critical * standard_error

  lower_bound = sample_mean - margin_of_error
  upper_bound = sample_mean + margin_of_error

  print(f"\nSample Mean: {sample_mean:.4f}")
  print(f"Sample Size: {sample_size}")
  print(f"Confidence Level: {confidence_level * 100}%")
  print(f"Margin of Error: {margin_of_error:.4f}")
  print(f"Confidence Interval: ({lower_bound:.4f}, {upper_bound:.4f})")

  return lower_bound, upper_bound

def explain_confidence_interval_significance():
  """
  Explains the significance of a confidence interval.
  """
  print("\nSignificance of a Confidence Interval:")
  print("A confidence interval provides a range of values within which the true population parameter (like the mean) is likely to lie, based on sample data.")
  print("The confidence level (e.g., 95%) represents the probability that the interval, if constructed for many samples, would contain the true population parameter.")
  print("It quantifies the uncertainty associated with estimating a population parameter from a sample.")
  print("- A wider interval indicates more uncertainty in the estimate.")
  print("- A narrower interval indicates greater precision in the estimate.")
  print("Confidence intervals are crucial for making inferences about the population and for understanding the reliability of statistical results.")
  print("If a hypothesized value for the population mean falls outside the confidence interval, it provides evidence against that hypothesized value (at the given confidence level).")

# Example Usage:

# Example 1: Using sample data (population standard deviation unknown - T-distribution)
sample_data_scores = [75, 80, 85, 90, 95, 78, 88, 92, 83, 87, 79, 86, 91, 84, 89]
calculate_confidence_interval_mean(sample_data_scores, confidence_level=0.95)

# Example 2: Using sample data with a known population standard deviation (Z-distribution)
# This is less common in practice, but demonstrates the Z-distribution case.
sample_data_heights = [165, 170, 175, 168, 172, 178, 169, 171, 176, 173]
known_pop_std_heights = 5.0 # Assume we know the population standard deviation
calculate_confidence_interval_mean(sample_data_heights, confidence_level=0.90, assumed_pop_std=known_pop_std_heights)

# Explain the significance
explain_confidence_interval_significance()
# Out:
# Using T-distribution (population standard deviation is unknown)
#
# Sample Mean: 85.4667
# Sample Size: 15
# Confidence Level: 95.0%
# Margin of Error: 3.1457
# Confidence Interval: (82.3210, 88.6124)
# Using Z-distribution (assumed population standard deviation is known)
#
# Sample Mean: 171.7000
# Sample Size: 10
# Confidence Level: 90.0%
# Margin of Error: 2.6007
# Confidence Interval: (169.0993, 174.3007)
#
# Significance of a Confidence Interval:
# A confidence interval provides a range of values within which the true population parameter (like the mean) is likely to lie, based on sample data.
# The confidence level (e.g., 95%) represents the probability that the interval, if constructed for many samples, would contain the true population parameter.
# It quantifies the uncertainty associated with estimating a population parameter from a sample.
# - A wider interval indicates more uncertainty in the estimate.
# - A narrower interval indicates greater precision in the estimate.
# ...

# %%
# QUE-10: Write a Python program to calculate the margin of error for a given confidence level using sample data.
#ANS-
import numpy as np
def calculate_margin_of_error(data, confidence_level=0.95, assumed_pop_std=None):
  """
  Calculates the margin of error for a sample mean.

  Args:
    data: A list or array of numerical data.
    confidence_level: The desired confidence level (e.g., 0.95 for 95%).
    assumed_pop_std: The known population standard deviation.
                     If None (default), the sample standard deviation is used,
                     and a t-distribution is used.

  Returns:
    The margin of error.
    Returns None if the data is empty or sample size is too small for t-distribution.
  """
  if not data:
    print("Error: Input data is empty.")
    return None

  sample_size = len(data)
  alpha = 1 - confidence_level

  if assumed_pop_std is not None:
    # Use Z-distribution if population standard deviation is known
    print("Calculating Margin of Error using Z-distribution...")
    standard_error = assumed_pop_std / np.sqrt(sample_size)
    z_critical = norm.ppf(1 - alpha / 2)
    margin_of_error = z_critical * standard_error
  else:
    # Use T-distribution if population standard deviation is unknown
    print("Calculating Margin of Error using T-distribution...")
    if sample_size < 2:
        print("Error: Sample size must be at least 2 for T-distribution.")
        return None
    sample_std = np.std(data, ddof=1) # Use sample standard deviation
    standard_error = sample_std / np.sqrt(sample_size)
    degrees_of_freedom = sample_size - 1
    t_critical = t.ppf(1 - alpha / 2, degrees_of_freedom)
    margin_of_error = t_critical * standard_error

  print(f"Sample Size: {sample_size}")
  print(f"Confidence Level: {confidence_level * 100}%")
  print(f"Margin of Error: {margin_of_error:.4f}")

  return margin_of_error

# Example Usage:

# Example 1: Calculate Margin of Error using sample data (population standard deviation unknown - T-distribution)
sample_data_values = [25, 28, 30, 22, 35, 27, 32, 29, 31, 26]
calculate_margin_of_error(sample_data_values, confidence_level=0.95)

# Example 2: Calculate Margin of Error with an assumed population standard deviation (Z-distribution)
sample_data_weights = [150, 155, 160, 148, 152, 165, 158, 162, 153, 159]
assumed_pop_std_weights = 8.0 # Assume known population standard deviation
calculate_margin_of_error(sample_data_weights, confidence_level=0.90, assumed_pop_std=assumed_pop_std_weights)
# Out:
# Calculating Margin of Error using T-distribution...
# Sample Size: 10
# Confidence Level: 95.0%
# Margin of Error: 2.6819
# Calculating Margin of Error using Z-distribution...
# Sample Size: 10
# Confidence Level: 90.0%
# Margin of Error: 4.1612
# np.float64(4.161187103004459)

# %%
# QUE-11: Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
#ANS-
def bayesian_inference_example(prior_prob_A, prob_B_given_A, prob_B_given_not_A):
  """
  Implements a simple Bayesian inference example using Bayes' Theorem.

  Args:
    prior_prob_A: The prior probability of event A (P(A)).
    prob_B_given_A: The probability of observing evidence B given that A is true (P(B|A)).
    prob_B_given_not_A: The probability of observing evidence B given that A is false (P(B|~A)).

  Returns:
    The posterior probability of A given B (P(A|B)).
  """
  # Calculate the prior probability of not A (P(~A))
  prior_prob_not_A = 1 - prior_prob_A

  # Calculate the probability of observing evidence B (P(B))
  # Using the law of total probability: P(B) = P(B|A) * P(A) + P(B|~A) * P(~A)
  prob_B = (prob_B_given_A * prior_prob_A) + (prob_B_given_not_A * prior_prob_not_A)

  # Avoid division by zero if P(B) is 0
  if prob_B == 0:
    print("Probability of evidence B is zero. Cannot perform Bayesian inference.")
    return None

  # Calculate the posterior probability of A given B (P(A|B)) using Bayes' Theorem
  # P(A|B) = [P(B|A) * P(A)] / P(B)
  posterior_prob_A_given_B = (prob_B_given_A * prior_prob_A) / prob_B

  print("Bayesian Inference Process:")
  print(f"  Prior Probability of A (P(A)): {prior_prob_A:.4f}")
  print(f"  Likelihood (P(B|A)): {prob_B_given_A:.4f}")
  print(f"  Prior Probability of not A (P(~A)): {prior_prob_not_A:.4f}")
  print(f"  Probability of B given not A (P(B|~A)): {prob_B_given_not_A:.4f}")
  print(f"  Probability of Evidence B (P(B)): {prob_B:.4f}")
  print(f"  Posterior Probability of A given B (P(A|B)): {posterior_prob_A_given_B:.4f}")

  return posterior_prob_A_given_B

# Example Usage:
# Scenario: A medical test for a rare disease.
# Event A: The person has the disease.
# Evidence B: The medical test is positive.

# Assume the following probabilities:
# Prior probability of the disease in the population (P(A))
prevalence = 0.01 # 1% of the population has the disease

# Probability of a positive test given the person has the disease (Sensitivity) (P(B|A))
sensitivity = 0.95 # The test is positive for 95% of people with the disease

# Probability of a positive test given the person does NOT have the disease (False Positive Rate) (P(B|~A))
false_positive_rate = 0.05 # The test is positive for 5% of people without the disease

print("Medical Test Scenario:")
posterior_probability = bayesian_inference_example(prior_prob_A=prevalence,
                                                 prob_B_given_A=sensitivity,
                                                 prob_B_given_not_A=false_positive_rate)

print("\nInterpretation of the result:")
if posterior_probability is not None:
  print(f"After a positive test result (Evidence B), the updated probability that the person has the disease (Event A) is {posterior_probability:.4f}.")
  print(f"This shows how new evidence (a positive test) updates our belief about the event (having the disease), compared to the initial prevalence ({prevalence:.4f}).")

print("\nAnother Example: Spam Filter")
# Event A: The email is spam.
# Evidence B: The email contains the word "free".

# Assume:
# Prior probability of an email being spam (P(A))
prior_spam_prob = 0.3 # 30% of emails are spam

# Probability of an email containing "free" given it is spam (P(B|A))
prob_free_given_spam = 0.8 # 80% of spam emails contain "free"

# Probability of an email containing "free" given it is NOT spam (P(B|~A))
prob_free_given_not_spam = 0.1 # 10% of non-spam emails contain "free"

print("\nSpam Filter Scenario:")
posterior_spam_prob = bayesian_inference_example(prior_prob_A=prior_spam_prob,
                                                prob_B_given_A=prob_free_given_spam,
                                                prob_B_given_not_A=prob_free_given_not_spam)

print("\nInterpretation of the result:")
if posterior_spam_prob is not None:
  print(f"Given the email contains the word 'free' (Evidence B), the updated probability that it is spam (Event A) is {posterior_spam_prob:.4f}.")
  print(f"The initial belief was that {prior_spam_prob:.4f} of emails are spam. Seeing the word 'free' increased this probability to {posterior_spam_prob:.4f}.")
# Out:
# Medical Test Scenario:
# Bayesian Inference Process:
#   Prior Probability of A (P(A)): 0.0100
#   Likelihood (P(B|A)): 0.9500
#   Prior Probability of not A (P(~A)): 0.9900
#   Probability of B given not A (P(B|~A)): 0.0500
#   Probability of Evidence B (P(B)): 0.0590
#   Posterior Probability of A given B (P(A|B)): 0.1610
#
# Interpretation of the result:
# After a positive test result (Evidence B), the updated probability that the person has the disease (Event A) is 0.1610.
# This shows how new evidence (a positive test) updates our belief about the event (having the disease), compared to the initial prevalence (0.0100).
#
# Another Example: Spam Filter
#
# Spam Filter Scenario:
# Bayesian Inference Process:
#   Prior Probability of A (P(A)): 0.3000
#   Likelihood (P(B|A)): 0.8000
#   Prior Probability of not A (P(~A)): 0.7000
#   Probability of B given not A (P(B|~A)): 0.1000
#   Probability of Evidence B (P(B)): 0.3100
#   Posterior Probability of A given B (P(A|B)): 0.7742
#
# ...

# %%
# QUE-12: Perform a Chi-square test for independence between two categorical variables in Python.
#ANS
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Create a sample contingency table (observed frequencies)
# Example: Data on gender and voting preference (e.g., Yes/No)
# Rows represent Gender, Columns represent Voting Preference
data = {'Voting_Preference_Yes': [30, 20],  # Observed frequencies for Yes votes
        'Voting_Preference_No': [20, 30]}   # Observed frequencies for No votes
index = ['Male', 'Female']
observed_data = pd.DataFrame(data, index=index)

print("Observed Frequencies:")
print(observed_data)

# Perform the Chi-square test for independence
# chi2_contingency returns: chi2 statistic, p-value, degrees of freedom, expected frequencies
chi2_statistic, p_value, dof, expected_frequencies = chi2_contingency(observed_data)

print("\nChi-square Test for Independence Results:")
print(f"Chi-square Statistic: {chi2_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")

print("\nExpected Frequencies (under the assumption of independence):")
print(pd.DataFrame(expected_frequencies, index=index, columns=observed_data.columns))

# Interpret the results
alpha = 0.05 # Significance level

print("\nInterpretation:")
if p_value < alpha:
  print(f"At the {alpha} significance level, we reject the null hypothesis.")
  print("There is sufficient evidence to conclude that there is a significant association (dependence) between Gender and Voting Preference.")
else:
  print(f"At the {alpha} significance level, we fail to reject the null hypothesis.")
  print("There is not sufficient evidence to conclude that there is a significant association (dependence) between Gender and Voting Preference.")

# Example with different data
data_2 = {'Outcome_A': [15, 25],
          'Outcome_B': [35, 45]}
index_2 = ['Group_X', 'Group_Y']
observed_data_2 = pd.DataFrame(data_2, index=index_2)

print("\n--- Another Example ---")
print("Observed Frequencies:")
print(observed_data_2)

chi2_statistic_2, p_value_2, dof_2, expected_frequencies_2 = chi2_contingency(observed_data_2)

print("\nChi-square Test for Independence Results:")
print(f"Chi-square Statistic: {chi2_statistic_2:.4f}")
print(f"P-value: {p_value_2:.4f}")
print(f"Degrees of Freedom: {dof_2}")

print("\nExpected Frequencies (under the assumption of independence):")
print(pd.DataFrame(expected_frequencies_2, index=index_2, columns=observed_data_2.columns))

print("\nInterpretation:")
if p_value_2 < alpha:
  print(f"At the {alpha} significance level, we reject the null hypothesis.")
  print("There is sufficient evidence to conclude that there is a significant association (dependence) between Group and Outcome.")
else:
  print(f"At the {alpha} significance level, we fail to reject the null hypothesis.")
  print("There is not sufficient evidence to conclude that there is a significant association (dependence) between Group and Outcome.")
# Out:
# Observed Frequencies:
#         Voting_Preference_Yes  Voting_Preference_No
# Male                       30                    20
# Female                     20                    30
#
# Chi-square Test for Independence Results:
# Chi-square Statistic: 3.2400
# P-value: 0.0719
# Degrees of Freedom: 1
#
# Expected Frequencies (under the assumption of independence):
#         Voting_Preference_Yes  Voting_Preference_No
# Male                     25.0                  25.0
# Female                   25.0                  25.0
#
# Interpretation:
# At the 0.05 significance level, we fail to reject the null hypothesis.
# There is not sufficient evidence to conclude that there is a significant association (dependence) between Gender and Voting Preference.
#
# --- Another Example ---
# Observed Frequencies:
#          Outcome_A  Outcome_B
# Group_X         15         35
# Group_Y         25         45
#
# Chi-square Test for Independence Results:
# Chi-square Statistic: 0.2100
# ...

# %%
# QUE13: Write a Python program to calculate the expected frequencies for a Chi-square test based on observed DATA
# ANS-

import pandas as pd
def calculate_expected_frequencies(observed_data):
  """
  Calculates the expected frequencies for a Chi-square test based on observed data.

  Args:
    observed_data: A pandas DataFrame representing the contingency table
                   of observed frequencies.

  Returns:
    A pandas DataFrame representing the expected frequencies.
  """
  # Get row and column totals
  row_totals = observed_data.sum(axis=1)
  col_totals = observed_data.sum(axis=0)
  grand_total = observed_data.sum().sum()

  # Initialize a DataFrame for expected frequencies
  expected_data = pd.DataFrame(index=observed_data.index, columns=observed_data.columns)

  # Calculate expected frequency for each cell
  for i in observed_data.index:
    for j in observed_data.columns:
      expected_data.loc[i, j] = (row_totals[i] * col_totals[j]) / grand_total

  return expected_data

# Example Usage (using the observed data from the previous example):
data_example = {'Voting_Preference_Yes': [30, 20],
                'Voting_Preference_No': [20, 30]}
index_example = ['Male', 'Female']
observed_data_example = pd.DataFrame(data_example, index=index_example)

print("Observed Frequencies:")
print(observed_data_example)

expected_frequencies_calculated = calculate_expected_frequencies(observed_data_example)

print("\nCalculated Expected Frequencies:")
print(expected_frequencies_calculated)

# Verify with chi2_contingency (it also returns expected frequencies)
# chi2_statistic, p_value, dof, expected_frequencies_from_statsmodels = chi2_contingency(observed_data_example)
# print("\nExpected Frequencies from statsmodels (for verification):")
# print(pd.DataFrame(expected_frequencies_from_statsmodels, index=index_example, columns=observed_data_example.columns))

# Another example
data_example_2 = {'Category_A': [10, 15, 20],
                  'Category_B': [5, 20, 15]}
index_example_2 = ['Group_1', 'Group_2', 'Group_3']
observed_data_example_2 = pd.DataFrame(data_example_2, index=index_example_2)

print("\n--- Another Example ---")
print("Observed Frequencies:")
print(observed_data_example_2)

expected_frequencies_calculated_2 = calculate_expected_frequencies(observed_data_example_2)

print("\nCalculated Expected Frequencies:")
expected_frequencies_calculated_2
# Out:
# Observed Frequencies:
#         Voting_Preference_Yes  Voting_Preference_No
# Male                       30                    20
# Female                     20                    30
#
# Calculated Expected Frequencies:
#        Voting_Preference_Yes Voting_Preference_No
# Male                    25.0                 25.0
# Female                  25.0                 25.0
#
# --- Another Example ---
# Observed Frequencies:
#          Category_A  Category_B
# Group_1          10           5
# Group_2          15          20
# Group_3          20          15
#
# Calculated Expected Frequencies:
#         Category_A Category_B
# Group_1   7.941176   7.058824
# Group_2  18.529412  16.470588
# Group_3  18.529412  16.470588

# %%
# QUE 14: Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
#ANS-
from scipy.stats import chisquare

def perform_goodness_of_fit_test(observed_frequencies, expected_frequencies):
  """
  Performs a Chi-square goodness-of-fit test to compare observed data to an expected distribution.

  Args:
    observed_frequencies: A list or array of observed frequencies for each category.
    expected_frequencies: A list or array of expected frequencies for each category.

  Returns:
    A tuple containing the chi2 statistic and the p-value.
  """
  if len(observed_frequencies) != len(expected_frequencies):
    print("Error: The number of observed and expected frequencies must be the same.")
    return None, None

  # Perform the Chi-square goodness-of-fit test
  chi2_statistic, p_value = chisquare(f_obs=observed_frequencies, f_exp=expected_frequencies)

  # Interpret the results
  print(f"Chi-square Goodness-of-Fit Test Results:")
  print(f"Chi-square Statistic: {chi2_statistic:.4f}")
  print(f"P-value: {p_value:.4f}")

  alpha = 0.05 # Significance level

  print("\nInterpretation:")
  if p_value < alpha:
    print(f"At the {alpha} significance level, we reject the null hypothesis.")
    print("There is sufficient evidence to conclude that the observed distribution is significantly different from the expected distribution.")
  else:
    print(f"At the {alpha} significance level, we fail to reject the null hypothesis.")
    print("There is not sufficient evidence to conclude that the observed distribution is significantly different from the expected distribution.")

  return chi2_statistic, p_value

# Example Usage:
# Assume we rolled a six-sided die 120 times and recorded the frequencies.
# We want to test if the die is fair (expected frequencies are equal for each face).

observed_rolls = [20, 22, 18, 25, 15, 20] # Observed frequencies for faces 1 to 6
total_rolls = sum(observed_rolls)
expected_rolls = [total_rolls / 6] * 6 # Expected frequencies for a fair die

print("Observed Frequencies:", observed_rolls)
print("Expected Frequencies (Fair Die):", expected_rolls)

perform_goodness_of_fit_test(observed_rolls, expected_rolls)

# Another Example:
# Assume we observed the number of customers arriving per hour at a store.
# We want to test if the arrivals follow a specific distribution (e.g., Poisson with a known rate).
# For simplicity, let's test against a uniform distribution here for demonstration.

observed_arrivals_per_hour = [10, 12, 8, 15, 9] # Observed frequencies for 5 different hours
total_arrivals = sum(observed_arrivals_per_hour)
expected_arrivals_uniform = [total_arrivals / len(observed_arrivals_per_hour)] * len(observed_arrivals_per_hour)

print("\n--- Another Example (Customer Arrivals) ---")
print("Observed Frequencies:", observed_arrivals_per_hour)
print("Expected Frequencies (Uniform Distribution):", expected_arrivals_uniform)

perform_goodness_of_fit_test(observed_arrivals_per_hour, expected_arrivals_uniform)
# Out:
# Observed Frequencies: [20, 22, 18, 25, 15, 20]
# Expected Frequencies (Fair Die): [20.0, 20.0, 20.0, 20.0, 20.0, 20.0]
# Chi-square Goodness-of-Fit Test Results:
# Chi-square Statistic: 2.9000
# P-value: 0.7154
#
# Interpretation:
# At the 0.05 significance level, we fail to reject the null hypothesis.
# There is not sufficient evidence to conclude that the observed distribution is significantly different from the expected distribution.
#
# --- Another Example (Customer Arrivals) ---
# Observed Frequencies: [10, 12, 8, 15, 9]
# Expected Frequencies (Uniform Distribution): [10.8, 10.8, 10.8, 10.8, 10.8]
# Chi-square Goodness-of-Fit Test Results:
# Chi-square Statistic: 2.8519
# P-value: 0.5829
#
# Interpretation:
# At the 0.05 significance level, we fail to reject the null hypothesis.
# There is not sufficient evidence to conclude that the observed distribution is significantly different from the expected distribution.
# ...
